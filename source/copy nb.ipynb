# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

ds_original = pd.read_csv("crimes_selected.csv")
ds_new = pd.read_csv("working_dataset.csv").dropna(subset=["AVER_AGE"]).reset_index()

# %%
ds_original.head()
# Out:
#   CASE_NUMBER                    Date                  Block  \
# 0    hs227745  03/27/2010 04:50:00 AM   124xx_s_michigan_ave
# 1    hs335199  05/31/2010 03:44:00 AM   026xx_s_ridgeway_ave
# 2    hs440368  08/01/2010 12:32:00 PM  124xx_s_eggleston_ave
# 3    hs460541  08/13/2010 01:03:00 PM        020xx_e_71st_st
# 4    hs501948  09/06/2010 06:55:00 PM        027xx_w_24th_st
#
#   Location Description  Domestic  Beat  District  Ward  Community Area  \
# 0                house     False   532       5.0   9.0            53.0
# 1                alley     False  1031      10.0  22.0            30.0
# 2                house     False   523       5.0  34.0            53.0
# 3               street     False   331       3.0   5.0            43.0
# 4                 auto     False  1034      10.0  12.0            30.0
#
#     Latitude  Longitude
# 0  41.668569 -87.620189
# 1  41.843516 -87.718433
# 2  41.668029 -87.633158
# 3  41.766250 -87.575528
# 4  41.848287 -87.693730

# %%
pd.DataFrame(ds_original["Location Description"].unique()).to_csv("val.csv")

# %%
ds_new.describe()
# Out:
#              index  NUM_CRIMES_DISTRICT  NUM_CRIMES_BEAT  \
# count  2465.000000          2465.000000      2465.000000
# mean   1251.281542           155.193509        14.627586
# std     724.021980            68.554760         7.656382
# min       0.000000            24.000000         1.000000
# 25%     623.000000           140.000000         9.000000
# 50%    1253.000000           150.000000        14.000000
# 75%    1877.000000           175.000000        19.000000
# max    2503.000000           291.000000        39.000000
#
#        NUM_CRIMES_COMM_AREA  NUM_CRIMES_WARD  NUM_CRIMES_BLOCK  \
# count           2465.000000      2465.000000       2465.000000
# mean              79.269777        88.527383          1.326572
# std               62.515107        49.278044          0.663310
# min                1.000000         3.000000          1.000000
# 25%               31.000000        41.000000          1.000000
# 50%               74.000000        89.000000          1.000000
# 75%               99.000000       118.000000          1.000000
# max              241.000000       194.000000          5.000000
#
#        NUM_CRIMES_ZIP_CODE  NUM_CRIMES_STREET_ORG   AREA_INCOME  \
# count          2465.000000            2465.000000   2465.000000
# mean            160.559026              65.193509  19601.209331
# std             139.155564              92.366718  13159.050137
# min               1.000000               0.000000   8535.000000
# 25%              64.000000               0.000000  13087.000000
# 50%             145.000000              32.000000  15920.000000
# 75%             186.000000              92.000000  20320.000000
# max            1963.000000            1134.000000  87163.000000
#
#        AREA_ASSAULT_HOMICIDE  ...  IS_DOMESTIC  NIGHT_CRIME  \
# count            2465.000000  ...  2465.000000  2465.000000
# mean               29.047465  ...     0.177282     0.009331
# std                15.187182  ...     0.381985     0.096163
# min                 0.000000  ...     0.000000     0.000000
# 25%                12.700000  ...     0.000000     0.000000
# 50%                33.400000  ...     0.000000     0.000000
# 75%                40.900000  ...     0.000000     0.000000
# max                70.300000  ...     1.000000     1.000000
#
#        IS_KILLED_A_CHILD  MULTIPLE_ARRESTS  HAS_STREET_ORGANIZATION  \
# count        2465.000000       2465.000000              2465.000000
# mean            0.085598          0.158621                 0.696146
# std             0.279827          0.365396                 0.460014
# min             0.000000          0.000000                 0.000000
# 25%             0.000000          0.000000                 0.000000
# 50%             0.000000          0.000000                 1.000000
# 75%             0.000000          0.000000                 1.000000
# max             1.000000          1.000000                 1.000000
#
#          IS_RATIAL     AVER_AGE  AVG_NUM_CHARGES  IMMEDIATE_ARREST  \
# count  2465.000000  2465.000000      2465.000000       2465.000000
# mean      0.163083    30.080792         1.907911          0.012170
# std       0.369516    13.888905         1.013532          0.109668
# min       0.000000    10.000000         1.000000          0.000000
# 25%       0.000000    25.000000         1.000000          0.000000
# 50%       0.000000    25.000000         2.000000          0.000000
# 75%       0.000000    35.000000         2.500000          0.000000
# max       1.000000    80.000000         4.000000          1.000000
#
#        IS_HOMICIDE
# count  2465.000000
# mean      0.492901
# std       0.500051
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000
#
# [8 rows x 28 columns]

# %%
sns.heatmap(ds_new.corr().iloc[0:10, 0:10], annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(ds_new.corr().iloc[0:10, 10:20], annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(ds_new.corr().iloc[0:10, 20:30], annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(ds_new.corr().iloc[10:20, 10:20], annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(ds_new.corr().iloc[10:20, 20:30], annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(ds_new.corr().iloc[20:30, 20:30], annot=True)
# Out:
# <AxesSubplot:>

# %%
# Plotting the Imbalance

x=['Non-Homicide (0)','Homicide (1)']
y=[len(ds_new[ds_new['IS_HOMICIDE'] == 0]), len(ds_new[ds_new['IS_HOMICIDE'] == 1])]
fig, ax = plt.subplots(figsize=(3, 4))
plt.bar(x,y, color=['green', 'blue', 'red'], width=0.5)
# plt.title('THE IMBALANCE IN THE DATASET')
plt.xlabel('Crime Type')
plt.ylabel('Count of Crimes')
plt.title("Class Imbalance")
print(str(len(ds_new[ds_new['IS_HOMICIDE'] == 0]) / (len(ds_new[ds_new['IS_HOMICIDE'] == 0]) + len(ds_new[ds_new['IS_HOMICIDE'] == 1]))))
# Out:
# 0.5070993914807302

# %%
from sklearn.metrics import precision_recall_fscore_support, mean_absolute_error, mean_squared_error, accuracy_score,\
    max_error

# for average -> "macro" or "micro"
def print_classifier_scores(true_y, pred_y, beta=1.0, average="macro"):
    
    (pr, rec, f_sc, su) = precision_recall_fscore_support(y_true=true_y, y_pred=pred_y, beta=beta, average=average)
    acc = accuracy_score(y_true=true_y, y_pred=pred_y)
    print("Accuracy:\t" + str(acc))
    print("Precision:\t" + str(pr))
    print("Recall:\t\t" + str(rec))
    print("F-measure" + ":\t" + str(f_sc))
    print("(beta " + str(beta) + ")")

# %%
from sklearn import model_selection
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.base import clone

def k_fold(X: pd.DataFrame, y: pd.Series, n_folds: int, classifier, verbose=False):

    kf = model_selection.KFold(n_splits=n_folds)
    i_train = 0
    i_test = 0
    j = 1
    max_score = 0
    curr_test_score = 0
    
    """
    if model_type=="tree":
        curr_tree = DecisionTreeClassifier(max_depth=5)
    elif model_type=="grad_boost":
        curr_tree = GradientBoostingClassifier()
    elif model_type=="random_forest":
        curr_tree = RandomForestClassifier(n_estimators=20)
        """
    

    for train_indexes, test_indexes in kf.split(X, y):
        curr_classifier = clone(classifier)
        curr_classifier = curr_classifier.fit(X.iloc[train_indexes], y[train_indexes])
        
        curr_train_score = curr_classifier.score(X.iloc[train_indexes], y[train_indexes])
        curr_test_score = curr_classifier.score(X.iloc[test_indexes], y[test_indexes])

        if verbose:
            print("Fold " + str(j) + "/" + str(n_folds))
            print("--------MODEL " + str(j) + " QUALITY--------")

            print("-------| Training |-----------")

            print_classifier_scores(true_y=y[train_indexes], 
                                pred_y=curr_classifier.predict(X.iloc[train_indexes]), beta=2.0)
        
            print("-------|   Test   |-----------")
            true_y = y[test_indexes]
            pred_y = curr_classifier.predict(X.iloc[test_indexes])
            print_classifier_scores(true_y=true_y, pred_y=pred_y, beta=2.0)


        if curr_test_score > max_score:
            best_classifier = curr_classifier
            max_score = curr_test_score

        j += 1
        i_train += curr_train_score
        i_test += curr_test_score

    mean_train_score = i_train / n_folds
    mean_test_score = i_test / n_folds

    return best_classifier, mean_train_score, mean_test_score

# %%
# extract info for trees


X: pd.DataFrame = ds_new.drop(columns=["CASE_NUMBER", "NUM_OF_DEAD", "IS_KILLED_A_CHILD",
                                            "IS_HOMICIDE", "VICTIM_RACE", "ARRESTED_RACE"])

y: pd.Series = ds_new["IS_HOMICIDE"]

# %%
from sklearn.preprocessing import OneHotEncoder


best_tree, mean_train_score, mean_test_score = k_fold(X, y, 10, classifier=DecisionTreeClassifier(max_depth=5), verbose=True)
# Out:
# Fold 1/10
# --------MODEL 1 QUALITY--------
# -------| Training |-----------
# Accuracy:	0.6582506762849414
# Precision:	0.7939097335508428
# Recall:		0.6666666666666666
# F-measure:	0.630811667644379
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.7530364372469636
# Precision:	0.8435897435897436
# Recall:		0.7300884955752213
# F-measure:	0.7162128417258377
# (beta 2.0)
# Fold 2/10
# --------MODEL 2 QUALITY--------
# -------| Training |-----------
# Accuracy:	0.6632100991884581
# Precision:	0.7974511930585684
# Recall:		0.6668153434433541
# F-measure:	0.6325334295005102
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.708502024291498
# Precision:	0.8105263157894738
# Recall:		0.7209302325581395
# F-measure:	0.6943104348238718
# (beta 2.0)
# Fold 3/10
# --------MODEL 3 QUALITY--------
# -------| Training |-----------
# Accuracy:	0.6663660955816051
# Precision:	0.7972602739726027
# Recall:		0.6734333627537511
# F-measure:	0.6394761651866399
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.680161943319838
# Precision:	0.8110047846889952
# Recall:		0.6623931623931624
# F-measure:	0.6335632221300498
# (beta 2.0)
# Fold 4/10
# --------MODEL 4 QUALITY--------
# -------| Training |-----------
# Accuracy:	0.675834084761046
# Precision:	0.8043004899292324
# Recall:		0.6731818181818182
# F-measure:	0.6422440142465706
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.5910931174089069
# Precision:	0.7449494949494949
# Recall:		0.6633333333333333
# F-measure:	0.6025744516373313
# (beta 2.0)
# Fold 5/10
# --------MODEL 5 QUALITY--------
# -------| Training |-----------
# Accuracy:	0.6735798016230838
# Precision:	0.8035811177428107
# Recall:		0.6706096451319381
# F-measure:	0.6392121401027977
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.6153846153846154
# Precision:	0.7513089005235603
# Recall:		0.685430463576159
# F-measure:	0.6295125164690383
# (beta 2.0)
# Fold 6/10
# --------MODEL 6 QUALITY--------
# -------| Training |-----------
# Accuracy:	0.6674177557458315
# Precision:	0.7989100817438692
# Recall:		0.6711229946524064
# F-measure:	0.6377481755667241
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.6707317073170732
# Precision:	0.7964824120603016
# Recall:		0.68359375
# F-measure:	0.6498391048524483
# (beta 2.0)
# Fold 7/10
# --------MODEL 7 QUALITY--------
# -------| Training |-----------
# Accuracy:	0.6656151419558359
# Precision:	0.7968236582694415
# Recall:		0.6731277533039648
# F-measure:	0.6389611379963106
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.6869918699186992
# Precision:	0.8149038461538461
# Recall:		0.6652173913043478
# F-measure:	0.6381674237935349
# (beta 2.0)
# Fold 8/10
# --------MODEL 8 QUALITY--------
# -------| Training |-----------
# Accuracy:	0.6678684091933303
# Precision:	0.7970814977973568
# Recall:		0.6767543859649123
# F-measure:	0.6429076306218529
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.6666666666666666
# Precision:	0.8119266055045872
# Recall:		0.6272727272727272
# F-measure:	0.5957668752944343
# (beta 2.0)
# Fold 9/10
# --------MODEL 9 QUALITY--------
# -------| Training |-----------
# Accuracy:	0.6633618747183416
# Precision:	0.7955665024630543
# Recall:		0.6720807726075505
# F-measure:	0.6372984751518279
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.7073170731707317
# Precision:	0.8260869565217391
# Recall:		0.6756756756756757
# F-measure:	0.6536705829529297
# (beta 2.0)
# Fold 10/10
# --------MODEL 10 QUALITY--------
# -------| Training |-----------
# Accuracy:	0.67598017124831
# Precision:	0.8018191841234841
# Recall:		0.6801601423487544
# F-measure:	0.6485504529892057
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.5894308943089431
# Precision:	0.7531709791983765
# Recall:		0.5990079365079365
# F-measure:	0.5480185575842811
# (beta 2.0)

# %%
print(mean_test_score)

classifier_path = "../models/decision_tree.csv"
save_model(best_tree, classifier_path)
# Out:
# 0.6669316349033937

# %%
import pickle

def save_model(model, model_path):
    with open(model_path, "wb") as model_file:
        pickle.dump(model, model_file)

# %%
from sklearn import tree

first_dot = tree.export_graphviz(best_tree,
        feature_names=X.columns.tolist(),
        class_names=list(map(lambda x: str(x), y.unique().tolist())),
        filled=True,
        rounded=True,
        out_file="../models/best_tree.dot")

# %%
import pydot

(graph,) = pydot.graph_from_dot_file('../models/best_tree.dot')
graph.write_png('../models/best_tree.png')

# %%
best_ensemble, mean_train_score, mean_test_score = k_fold(X, y, 10, classifier=GradientBoostingClassifier(), verbose=True)
print(mean_train_score, mean_test_score)
# Out:
# Fold 1/10
# --------MODEL 1 QUALITY--------
# -------| Training |-----------
# Accuracy:	0.7804328223624887
# Precision:	0.7850697529036291
# Recall:		0.7819671677662544
# F-measure:	0.7803822723899743
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.757085020242915
# Precision:	0.8054945054945055
# Recall:		0.7386738872011623
# F-measure:	0.7309822578298841
# (beta 2.0)
# Fold 2/10
# --------MODEL 2 QUALITY--------
# -------| Training |-----------
# Accuracy:	0.7759242560865645
# Precision:	0.7810170499603489
# Recall:		0.7766347601153742
# F-measure:	0.775193352077105
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.757085020242915
# Precision:	0.7633293445020609
# Recall:		0.7602154775982131
# F-measure:	0.7576393442622952
# (beta 2.0)
# Fold 3/10
# --------MODEL 3 QUALITY--------
# -------| Training |-----------
# Accuracy:	0.7826871055004508
# Precision:	0.7877695618530578
# Recall:		0.7840690471445247
# F-measure:	0.7824425687099925
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.6639676113360324
# Precision:	0.6858199402645427
# Recall:		0.6717948717948719
# F-measure:	0.6625327226847553
# (beta 2.0)
# Fold 4/10
# --------MODEL 4 QUALITY--------
# -------| Training |-----------
# Accuracy:	0.7944093778178539
# Precision:	0.8080764635603346
# Recall:		0.793546918198081
# F-measure:	0.7907520683856458
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.7206477732793523
# Precision:	0.7229109274563821
# Recall:		0.733573883161512
# F-measure:	0.7247216630598445
# (beta 2.0)
# Fold 5/10
# --------MODEL 5 QUALITY--------
# -------| Training |-----------
# Accuracy:	0.784941388638413
# Precision:	0.7935855428974695
# Recall:		0.7841554715839649
# F-measure:	0.78233333672207
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.659919028340081
# Precision:	0.6508597883597884
# Recall:		0.6573537527593819
# F-measure:	0.6541779431664412
# (beta 2.0)
# Fold 6/10
# --------MODEL 6 QUALITY--------
# -------| Training |-----------
# Accuracy:	0.7778278503830555
# Precision:	0.7842785483274733
# Recall:		0.7786578043830443
# F-measure:	0.7768683443261533
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.6910569105691057
# Precision:	0.6949806949806949
# Recall:		0.6872351694915254
# F-measure:	0.6858054226475279
# (beta 2.0)
# Fold 7/10
# --------MODEL 7 QUALITY--------
# -------| Training |-----------
# Accuracy:	0.7823343848580442
# Precision:	0.7862567678424939
# Recall:		0.7836183493993529
# F-measure:	0.7822846364058789
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.6666666666666666
# Precision:	0.6661659269375213
# Recall:		0.6615333554596747
# F-measure:	0.6610552904406768
# (beta 2.0)
# Fold 8/10
# --------MODEL 8 QUALITY--------
# -------| Training |-----------
# Accuracy:	0.7845876520955385
# Precision:	0.7890182972281604
# Recall:		0.7862100222753362
# F-measure:	0.7846468057966087
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.7276422764227642
# Precision:	0.7320537844285404
# Recall:		0.714572192513369
# F-measure:	0.7137545515154623
# (beta 2.0)
# Fold 9/10
# --------MODEL 9 QUALITY--------
# -------| Training |-----------
# Accuracy:	0.7868409193330329
# Precision:	0.7908595299130581
# Recall:		0.7883328455760414
# F-measure:	0.7869102702269914
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.7154471544715447
# Precision:	0.7316959064327485
# Recall:		0.6982982982982984
# F-measure:	0.6942920091379885
# (beta 2.0)
# Fold 10/10
# --------MODEL 10 QUALITY--------
# -------| Training |-----------
# Accuracy:	0.7832356917530419
# Precision:	0.7877209486842669
# Recall:		0.784029233494207
# F-measure:	0.7827317973729271
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.5934959349593496
# Precision:	0.6792717086834734
# Recall:		0.6015873015873016
# F-measure:	0.5650343808238545
# (beta 2.0)
# 0.7833221448828483 0.6953013396530727

# %%
best_forest, mean_train_score, mean_test_score = k_fold(X, y, 10, classifier=RandomForestClassifier(), verbose=True)
# Out:
# Fold 1/10
# --------MODEL 1 QUALITY--------
# -------| Training |-----------
# Accuracy:	1.0
# Precision:	1.0
# Recall:		1.0
# F-measure:	1.0
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.708502024291498
# Precision:	0.7068376068376069
# Recall:		0.7077664773477743
# F-measure:	0.7074605361072849
# (beta 2.0)
# Fold 2/10
# --------MODEL 2 QUALITY--------
# -------| Training |-----------
# Accuracy:	1.0
# Precision:	1.0
# Recall:		1.0
# F-measure:	1.0
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.728744939271255
# Precision:	0.728835453100159
# Recall:		0.726941269215609
# F-measure:	0.7269425649012407
# (beta 2.0)
# Fold 3/10
# --------MODEL 3 QUALITY--------
# -------| Training |-----------
# Accuracy:	1.0
# Precision:	1.0
# Recall:		1.0
# F-measure:	1.0
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.659919028340081
# Precision:	0.6614111154907372
# Recall:		0.6615384615384615
# F-measure:	0.6605125943195601
# (beta 2.0)
# Fold 4/10
# --------MODEL 4 QUALITY--------
# -------| Training |-----------
# Accuracy:	1.0
# Precision:	1.0
# Recall:		1.0
# F-measure:	1.0
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.7044534412955465
# Precision:	0.6950564034505641
# Recall:		0.7020274914089347
# F-measure:	0.6993033191109077
# (beta 2.0)
# Fold 5/10
# --------MODEL 5 QUALITY--------
# -------| Training |-----------
# Accuracy:	1.0
# Precision:	1.0
# Recall:		1.0
# F-measure:	1.0
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.6558704453441295
# Precision:	0.6474706115440496
# Recall:		0.6540424944812362
# F-measure:	0.6506246148980604
# (beta 2.0)
# Fold 6/10
# --------MODEL 6 QUALITY--------
# -------| Training |-----------
# Accuracy:	1.0
# Precision:	1.0
# Recall:		1.0
# F-measure:	1.0
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.6544715447154471
# Precision:	0.653953953953954
# Recall:		0.6527409957627119
# F-measure:	0.6526427554539886
# (beta 2.0)
# Fold 7/10
# --------MODEL 7 QUALITY--------
# -------| Training |-----------
# Accuracy:	1.0
# Precision:	1.0
# Recall:		1.0
# F-measure:	1.0
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.6747967479674797
# Precision:	0.6734152007965484
# Recall:		0.6734152007965484
# F-measure:	0.6734152007965484
# (beta 2.0)
# Fold 8/10
# --------MODEL 8 QUALITY--------
# -------| Training |-----------
# Accuracy:	1.0
# Precision:	1.0
# Recall:		1.0
# F-measure:	1.0
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.6504065040650406
# Precision:	0.6456290849673203
# Recall:		0.64298128342246
# F-measure:	0.6430613361366172
# (beta 2.0)
# Fold 9/10
# --------MODEL 9 QUALITY--------
# -------| Training |-----------
# Accuracy:	1.0
# Precision:	1.0
# Recall:		1.0
# F-measure:	1.0
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.7073170731707317
# Precision:	0.7054263565891472
# Recall:		0.7069069069069069
# F-measure:	0.7063379775065346
# (beta 2.0)
# Fold 10/10
# --------MODEL 10 QUALITY--------
# -------| Training |-----------
# Accuracy:	1.0
# Precision:	1.0
# Recall:		1.0
# F-measure:	1.0
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.6341463414634146
# Precision:	0.6576807228915662
# Recall:		0.6384920634920634
# F-measure:	0.6275446371771491
# (beta 2.0)

# %%
# Plotting the Imbalance
def plot_scores(x_values, train_scores, test_scores, to_print):
    fig, ax = plt.subplots()
    
    ax.plot(x_values, train_scores)
    ax.plot(x_values, test_scores)
    
    plt.xlabel(to_print)
    plt.ylabel('Scores')
    plt.ylim(0, 1)
    plt.title("Training and test scores")
    plt.show()

# %%
mean_train_score = []
mean_test_score = []

for i in range(5, 151, 5):
    best_forest, train_sc, test_sc = k_fold(X, y, 10, classifier=RandomForestClassifier(n_estimators=i))
    mean_train_score.append(train_sc)
    mean_test_score.append(test_sc)
    
plot_scores([i for i in range(5, 151, 5)], mean_train_score, mean_test_score, "Num of trees")

# %%
import numpy as np

for crit in {"gini", "entropy", "log_loss"}:
    mean_train_score = []
    mean_test_score = []
    print(f"Criterion: {crit}")
    for i in range(5, 151, 5):
        best_forest, train_sc, test_sc = k_fold(X, y, 10, classifier=RandomForestClassifier(n_estimators=i, criterion=crit))
        mean_train_score.append(train_sc)
        mean_test_score.append(test_sc)
        
    print(f"Media score: {np.average(mean_test_score)}")

    plot_scores([i for i in range(5, 151, 5)], mean_train_score, mean_test_score, "Num of trees")
# Out:
# Criterion: gini
# Media score: 0.680104615823486
# Criterion: entropy
# Media score: 0.6809423652940985
# Criterion: log_loss
# Media score: 0.6808333059039094

# %%
mean_train_score = []
mean_test_score = []

for i in range(3, 26):
    best_forest, train_sc, test_sc = k_fold(X, y, 10, classifier=RandomForestClassifier(max_depth=i))
    mean_train_score.append(train_sc)
    mean_test_score.append(test_sc)

print(f"Media score: {np.average(mean_test_score)}")

plot_scores([i for i in range(3, 26)], mean_train_score, mean_test_score, "Tree Depth")
# Out:
# Media score: 0.6912827382102372

# %%
for crit in {"gini", "entropy", "log_loss"}:
    print(f"Criterion: {crit}")
    
    mean_train_score = []
    mean_test_score = []

    for i in range(3, 26):
        best_forest, train_sc, test_sc = k_fold(X, y, 10, classifier=DecisionTreeClassifier(max_depth=i, criterion=crit))
        mean_train_score.append(train_sc)
        mean_test_score.append(test_sc)

    print(f"Media score: {np.average(mean_test_score)}")

    plot_scores([i for i in range(3, 26)], mean_train_score, mean_test_score, "Tree Depth")
# Out:
# Criterion: gini
# Media score: 0.6772032148239103
# Criterion: entropy
# Media score: 0.6724485984518356
# Criterion: log_loss
# Media score: 0.6727499166384024

# %%
for loss in {"exponential", "log_loss"}:
    mean_train_score = []
    mean_test_score = []
    print(f"Loss: {crit}")
    for i in range(5, 151, 5):
        best_forest, train_sc, test_sc = k_fold(X, y, 10, classifier=GradientBoostingClassifier(n_estimators=i, loss=loss))
        mean_train_score.append(train_sc)
        mean_test_score.append(test_sc)
        
    print(f"Media score: {np.average(mean_test_score)}")

    plot_scores([i for i in range(5, 151, 5)], mean_train_score, mean_test_score, "Num of trees")
# Out:
# Loss: log_loss
# Media score: 0.6908877258813073
# Loss: log_loss
# Media score: 0.688238208090583

# %%
from sklearn.ensemble import AdaBoostClassifier


mean_train_score = []
mean_test_score = []
for i in range(5, 151, 5):
    best_forest, train_sc, test_sc = k_fold(X, y, 10, classifier=AdaBoostClassifier(n_estimators=i))
    mean_train_score.append(train_sc)
    mean_test_score.append(test_sc)

print(f"Media score: {np.average(mean_test_score)}")

plot_scores([i for i in range(5, 151, 5)], mean_train_score, mean_test_score, "Num of trees")
# Out:
# Media score: 0.6692882064448173

# %%
from sklearn.naive_bayes import CategoricalNB
from sklearn.preprocessing import LabelEncoder

# Create an instance of the LabelEncoder
encoder = LabelEncoder()
encoder_beat = LabelEncoder()



complete_df: pd.DataFrame = pd.merge(ds_original, ds_new, on="CASE_NUMBER")

df_for_nb = complete_df.drop(["CASE_NUMBER", "Date", "Block", "Latitude", "Longitude", "NUM_CRIMES_DISTRICT", "NUM_CRIMES_BEAT", "NUM_CRIMES_COMM_AREA", "NUM_CRIMES_WARD", "NUM_CRIMES_BLOCK", "NUM_CRIMES_ZIP_CODE", "NUM_CRIMES_STREET_ORG", "AVG_NUM_CHARGES", "AREA_INCOME", "AREA_ASSAULT_HOMICIDE", "AREA_FIREARM", "AREA_POVERTY_HEALTH", "AREA_HIGH_SCHOOL_DIPLOMA", "AREA_UNEMPLOYMENT", "AREA_BIRTH_RATE", "NUM_OF_DEAD", "NUM_OF_VICTIMS", "IS_KILLED_A_CHILD", "MULTIPLE_ARRESTS", "ARRESTED_RACE", "VICTIM_RACE", "index"], axis=1)
df_for_nb["AVER_AGE"] = df_for_nb["AVER_AGE"].apply(lambda x: x - (x % 10))

df_for_nb["Location Description"] = encoder.fit_transform(df_for_nb["Location Description"])
df_for_nb["Beat"] = encoder_beat.fit_transform(df_for_nb["Beat"])



X = df_for_nb.drop(["IS_HOMICIDE"], axis=1)
y = df_for_nb["IS_HOMICIDE"]

print(X.nunique())

best_nb, score_train, score_test = k_fold(X, y, 10, CategoricalNB(min_categories=X.nunique()), verbose=True)


print("Score test: " + str(score_test))
# Out:
# Location Description        87
# Domestic                     2
# Beat                       260
# District                    22
# Ward                        50
# Community Area              76
# NUM_OF_ARREST                6
# IS_DOMESTIC                  2
# NIGHT_CRIME                  2
# HAS_STREET_ORGANIZATION      2
# IS_RATIAL                    2
# AVER_AGE                     8
# IMMEDIATE_ARREST             2
# dtype: int64
# Fold 1/10
# --------MODEL 1 QUALITY--------
# -------| Training |-----------
# Accuracy:	0.7714156898106402
# Precision:	0.7713341346153846
# Recall:		0.7710990263583752
# F-measure:	0.7711234254467337
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.6842105263157895
# Precision:	0.6941322092867657
# Recall:		0.6916193369436006
# F-measure:	0.6864155017257412
# (beta 2.0)
# Fold 2/10
# --------MODEL 2 QUALITY--------
# -------| Training |-----------
# Accuracy:	0.7732191163210099
# Precision:	0.7733662873538539
# Recall:		0.7733340543547116
# F-measure:	0.7732558873226829
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.7449392712550608
# Precision:	0.7463618157543391
# Recall:		0.7424451451846013
# F-measure:	0.742271420447365
# (beta 2.0)
# Fold 3/10
# --------MODEL 3 QUALITY--------
# -------| Training |-----------
# Accuracy:	0.7745716862037872
# Precision:	0.7744727050930161
# Recall:		0.7745441529970186
# F-measure:	0.7745234090661886
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.728744939271255
# Precision:	0.7288552321007081
# Recall:		0.7294871794871796
# F-measure:	0.7289849628010592
# (beta 2.0)
# Fold 4/10
# --------MODEL 4 QUALITY--------
# -------| Training |-----------
# Accuracy:	0.7822362488728585
# Precision:	0.7823137636817924
# Recall:		0.7821523825012198
# F-measure:	0.7821479046449998
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.7125506072874493
# Precision:	0.7022715161204369
# Recall:		0.7086941580756014
# F-measure:	0.706443155528395
# (beta 2.0)
# Fold 5/10
# --------MODEL 5 QUALITY--------
# -------| Training |-----------
# Accuracy:	0.7840396753832282
# Precision:	0.7843248719719575
# Recall:		0.7838798127471476
# F-measure:	0.783843746543569
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.708502024291498
# Precision:	0.6998677248677249
# Recall:		0.7084713024282561
# F-measure:	0.7047175782443581
# (beta 2.0)
# Fold 6/10
# --------MODEL 6 QUALITY--------
# -------| Training |-----------
# Accuracy:	0.7823343848580442
# Precision:	0.7823941156112755
# Recall:		0.7824133879954567
# F-measure:	0.7823646833133191
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.6951219512195121
# Precision:	0.6946232990375041
# Recall:		0.6941207627118644
# F-measure:	0.6941548480424755
# (beta 2.0)
# Fold 7/10
# --------MODEL 7 QUALITY--------
# -------| Training |-----------
# Accuracy:	0.7805317710680487
# Precision:	0.7804228913528526
# Recall:		0.7805090462798902
# F-measure:	0.780483590205351
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.7154471544715447
# Precision:	0.7146165552835307
# Recall:		0.7153003650846332
# F-measure:	0.7150418248529564
# (beta 2.0)
# Fold 8/10
# --------MODEL 8 QUALITY--------
# -------| Training |-----------
# Accuracy:	0.7751239296980622
# Precision:	0.7749656428646938
# Recall:		0.77489187519308
# F-measure:	0.7749041055351309
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.6829268292682927
# Precision:	0.679637526652452
# Recall:		0.6802139037433155
# F-measure:	0.6800692574066949
# (beta 2.0)
# Fold 9/10
# --------MODEL 9 QUALITY--------
# -------| Training |-----------
# Accuracy:	0.7814330779630464
# Precision:	0.7812771810258352
# Recall:		0.7812904432087926
# F-measure:	0.7812876890521061
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.6544715447154471
# Precision:	0.6557539682539683
# Recall:		0.6571571571571572
# F-measure:	0.6553030303030303
# (beta 2.0)
# Fold 10/10
# --------MODEL 10 QUALITY--------
# -------| Training |-----------
# Accuracy:	0.782785038305543
# Precision:	0.7827485213830755
# Recall:		0.7827714944994231
# F-measure:	0.7827652714664488
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.6504065040650406
# Precision:	0.6541867954911433
# Recall:		0.651984126984127
# F-measure:	0.6501840218287962
# (beta 2.0)
# Score test: 0.697732135216089

# %%
for column in X.columns:
    X_reduced = X.drop([column], axis=1)
    best_nb, score_train, score_test = k_fold(X_reduced, y, 10, CategoricalNB(min_categories=X_reduced.nunique()))
    print(f"---------| Dropping {column} |-------")
    print("Score train: " + str(score_train))
    print("Score test: " + str(score_test))
# Out:
# ---------| Dropping Location Description |-------
# Score train: 0.634437420734366
# Score test: 0.5257183766169644
# ---------| Dropping Domestic |-------
# Score train: 0.7792648619127129
# Score test: 0.6993565057108061
# ---------| Dropping Beat |-------
# Score train: 0.7586653871738909
# Score test: 0.7111368947697574
# ---------| Dropping District |-------
# Score train: 0.7798961018273611
# Score test: 0.7066538296961917
# ---------| Dropping Ward |-------
# Score train: 0.7810678211088675
# Score test: 0.7078815707185412
# ---------| Dropping Community Area |-------
# Score train: 0.7840430888087998
# Score test: 0.7119400283071656
# ---------| Dropping NUM_OF_ARREST |-------
# Score train: 0.7780029509876788
# Score test: 0.700167868075442
# ---------| Dropping IS_DOMESTIC |-------
# Score train: 0.7806622736421372
# Score test: 0.7058523419242289
# ---------| Dropping NIGHT_CRIME |-------
# Score train: 0.7788140662391486
# Score test: 0.6989483558803199
# ---------| Dropping HAS_STREET_ORGANIZATION |-------
# Score train: 0.780617187979378
# Score test: 0.7013873802705639
# ---------| Dropping IS_RATIAL |-------
# Score train: 0.7786337642241304
# Score test: 0.6981386392811296
# ---------| Dropping AVER_AGE |-------
# Score train: 0.7793550129202222
# Score test: 0.7062489713965964
# ---------| Dropping IMMEDIATE_ARREST |-------
# Score train: 0.7765602910514204
# Score test: 0.6973239853856028

# %%
# conclusion: the most important is location description, whereas Beat (we could expect it due to the high number of values)
# push the model towards overfitting -> by removing it train_score lowered and test_scored improved
X_corrected = X.drop(["Beat"], axis=1)

# GO ON with the reduction
for column in X_corrected.columns:
    X_reduced = X_corrected.drop([column], axis=1)
    best_nb, score_train, score_test = k_fold(X_reduced, y, 10, CategoricalNB(min_categories=X_reduced.nunique()))
    print(f"---------| Dropping {column} |-------")
    print("Score train: " + str(score_train))
    print("Score test: " + str(score_test))
# Out:
# ---------| Dropping Location Description |-------
# Score train: 0.6025240250301621
# Score test: 0.5403442941312004
# ---------| Dropping Domestic |-------
# Score train: 0.7594768681495292
# Score test: 0.7107287449392713
# ---------| Dropping District |-------
# Score train: 0.7619562341951285
# Score test: 0.7139692571014778
# ---------| Dropping Ward |-------
# Score train: 0.7572681176705321
# Score test: 0.7212797472104275
# ---------| Dropping Community Area |-------
# Score train: 0.7540681734231499
# Score test: 0.711138540535203
# ---------| Dropping NUM_OF_ARREST |-------
# Score train: 0.7569526399392736
# Score test: 0.7095059412132583
# ---------| Dropping IS_DOMESTIC |-------
# Score train: 0.7619105796281074
# Score test: 0.7147904940587868
# ---------| Dropping NIGHT_CRIME |-------
# Score train: 0.7586202811931223
# Score test: 0.7119499028998387
# ---------| Dropping HAS_STREET_ORGANIZATION |-------
# Score train: 0.7614150436979427
# Score test: 0.7131546032059513
# ---------| Dropping IS_RATIAL |-------
# Score train: 0.7585751752123536
# Score test: 0.7099206741055266
# ---------| Dropping AVER_AGE |-------
# Score train: 0.7587556194534375
# Score test: 0.7172147065600211
# ---------| Dropping IMMEDIATE_ARREST |-------
# Score train: 0.7564567382849405
# Score test: 0.7099206741055266

# %%
# SAME THING FOR COMM AREA
X_corrected = X_corrected.drop(["Community Area"], axis=1)

# GO ON with the reduction
for column in X_corrected.columns:
    X_reduced = X_corrected.drop([column], axis=1)
    best_nb, score_train, score_test = k_fold(X_reduced, y, 10, CategoricalNB(min_categories=X_reduced.nunique()))
    print(f"---------| Dropping {column} |-------")
    print("Score train: " + str(score_train))
    print("Score test: " + str(score_test))
# Out:
# ---------| Dropping Location Description |-------
# Score train: 0.5942301526573316
# Score test: 0.548854547249926
# ---------| Dropping Domestic |-------
# Score train: 0.7538876275920193
# Score test: 0.7147822652315592
# ---------| Dropping District |-------
# Score train: 0.7572685443487287
# Score test: 0.7200717553734242
# ---------| Dropping Ward |-------
# Score train: 0.7442868399034326
# Score test: 0.7172311642144763
# ---------| Dropping NUM_OF_ARREST |-------
# Score train: 0.7545186643265738
# Score test: 0.7139873605213785
# ---------| Dropping IS_DOMESTIC |-------
# Score train: 0.7593861279197488
# Score test: 0.7245301339653073
# ---------| Dropping NIGHT_CRIME |-------
# Score train: 0.7536626056384101
# Score test: 0.7111385405352029
# ---------| Dropping HAS_STREET_ORGANIZATION |-------
# Score train: 0.7560058816573482
# Score test: 0.7204716763766829
# ---------| Dropping IS_RATIAL |-------
# Score train: 0.7544285742730927
# Score test: 0.7115450446002436
# ---------| Dropping AVER_AGE |-------
# Score train: 0.7538419120709701
# Score test: 0.713979131694151
# ---------| Dropping IMMEDIATE_ARREST |-------
# Score train: 0.7533921932519014
# Score test: 0.7087093907376321

# %%
# SAME THING FOR Ward
X_corrected = X_corrected.drop(["Ward"], axis=1)

# GO ON with the reduction
for column in X_corrected.columns:
    X_reduced = X_corrected.drop([column], axis=1)
    best_nb, score_train, score_test = k_fold(X_reduced, y, 10, CategoricalNB(min_categories=X_reduced.nunique()))
    print(f"---------| Dropping {column} |-------")
    print("Score train: " + str(score_train))
    print("Score test: " + str(score_test))
# Out:
# ---------| Dropping Location Description |-------
# Score train: 0.5858911743037323
# Score test: 0.5666995819755769
# ---------| Dropping Domestic |-------
# Score train: 0.7502816482456821
# Score test: 0.722902471939699
# ---------| Dropping District |-------
# Score train: 0.745413432886161
# Score test: 0.7293867877950035
# ---------| Dropping NUM_OF_ARREST |-------
# Score train: 0.7468112103397537
# Score test: 0.7221075672295184
# ---------| Dropping IS_DOMESTIC |-------
# Score train: 0.7574036591109408
# Score test: 0.7358908528356538
# ---------| Dropping NIGHT_CRIME |-------
# Score train: 0.7440614319076457
# Score test: 0.7147987228860144
# ---------| Dropping HAS_STREET_ORGANIZATION |-------
# Score train: 0.7502364000388481
# Score test: 0.7216928343372503
# ---------| Dropping IS_RATIAL |-------
# Score train: 0.7447827009217468
# Score test: 0.71682301438399
# ---------| Dropping AVER_AGE |-------
# Score train: 0.7530315282678369
# Score test: 0.725334913268161
# ---------| Dropping IMMEDIATE_ARREST |-------
# Score train: 0.7418077583099641
# Score test: 0.7139890062868239

# %%
# SAME FOR DISTRICT
X_corrected = X_corrected.drop(["District"], axis=1)

# GO ON with the reduction
for column in X_corrected.columns:
    X_reduced = X_corrected.drop([column], axis=1)
    best_nb, score_train, score_test = k_fold(X_reduced, y, 10, CategoricalNB(min_categories=X_reduced.nunique()))
    print(f"---------| Dropping {column} |-------")
    print("Score train: " + str(score_train))
    print("Score test: " + str(score_test))
# Out:
# ---------| Dropping Location Description |-------
# Score train: 0.5765600675533176
# Score test: 0.5747951022020341
# ---------| Dropping Domestic |-------
# Score train: 0.7552856082257055
# Score test: 0.7366906948421711
# ---------| Dropping NUM_OF_ARREST |-------
# Score train: 0.7478487494874783
# Score test: 0.7237121885388895
# ---------| Dropping IS_DOMESTIC |-------
# Score train: 0.7632636168250999
# Score test: 0.7557651163556169
# ---------| Dropping NIGHT_CRIME |-------
# Score train: 0.7459092532684566
# Score test: 0.7277640630657318
# ---------| Dropping HAS_STREET_ORGANIZATION |-------
# Score train: 0.750552649854462
# Score test: 0.722886014285244
# ---------| Dropping IS_RATIAL |-------
# Score train: 0.7474423893003738
# Score test: 0.7285721338994767
# ---------| Dropping AVER_AGE |-------
# Score train: 0.7603342678263103
# Score test: 0.7488529014844805
# ---------| Dropping IMMEDIATE_ARREST |-------
# Score train: 0.7425288647799906
# Score test: 0.7233040387084033

# %%
# retain only Street Location
X_corrected = X_corrected["Location Description"]

# GO ON with the reduction

best_nb, score_train, score_test = k_fold(X_reduced, y, 10, CategoricalNB(min_categories=X_reduced.nunique()), verbose=True)
print("Score train: " + str(score_train))
print("Score test: " + str(score_test))
# Out:
# Fold 1/10
# --------MODEL 1 QUALITY--------
# -------| Training |-----------
# Accuracy:	0.7403065825067628
# Precision:	0.7419904558798684
# Recall:		0.7412344184389028
# F-measure:	0.7404963114596936
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.7489878542510121
# Precision:	0.7513795821836815
# Recall:		0.7527077004358738
# F-measure:	0.7504131861653692
# (beta 2.0)
# Fold 2/10
# --------MODEL 2 QUALITY--------
# -------| Training |-----------
# Accuracy:	0.7479711451758341
# Precision:	0.7534057394704576
# Recall:		0.7487369250498277
# F-measure:	0.7470648171862326
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.7408906882591093
# Precision:	0.7409847888801468
# Recall:		0.7414597293391144
# F-measure:	0.7410842759765153
# (beta 2.0)
# Fold 3/10
# --------MODEL 3 QUALITY--------
# -------| Training |-----------
# Accuracy:	0.7389540126239855
# Precision:	0.7392813449687314
# Recall:		0.7392904934088773
# F-measure:	0.7390761719847858
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.728744939271255
# Precision:	0.7284590163934426
# Recall:		0.7290598290598291
# F-measure:	0.7287478649323347
# (beta 2.0)
# Fold 4/10
# --------MODEL 4 QUALITY--------
# -------| Training |-----------
# Accuracy:	0.739404869251578
# Precision:	0.7411827155956077
# Recall:		0.7390364286875915
# F-measure:	0.7385754758073187
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.7327935222672065
# Precision:	0.7264822134387352
# Recall:		0.7362886597938144
# F-measure:	0.7316755206466121
# (beta 2.0)
# Fold 5/10
# --------MODEL 5 QUALITY--------
# -------| Training |-----------
# Accuracy:	0.7488728584310189
# Precision:	0.7546397653168156
# Recall:		0.7481734552737438
# F-measure:	0.7467170289866402
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.7206477732793523
# Precision:	0.7282508554882864
# Recall:		0.7392729028697571
# F-measure:	0.727245145631068
# (beta 2.0)
# Fold 6/10
# --------MODEL 6 QUALITY--------
# -------| Training |-----------
# Accuracy:	0.7494366831906264
# Precision:	0.7541629179632365
# Recall:		0.7501767094506651
# F-measure:	0.748708199430645
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.7520325203252033
# Precision:	0.7622717088736506
# Recall:		0.755760063559322
# F-measure:	0.7520325203252032
# (beta 2.0)
# Fold 7/10
# --------MODEL 7 QUALITY--------
# -------| Training |-----------
# Accuracy:	0.7327625056331681
# Precision:	0.7330782328194865
# Recall:		0.7320927548482534
# F-measure:	0.7320413621437201
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.7154471544715447
# Precision:	0.7167339376695561
# Recall:		0.7174244938599403
# F-measure:	0.7161914047493516
# (beta 2.0)
# Fold 8/10
# --------MODEL 8 QUALITY--------
# -------| Training |-----------
# Accuracy:	0.7359170797656602
# Precision:	0.7362010122661299
# Recall:		0.7350726793814937
# F-measure:	0.7350387057064773
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.6951219512195121
# Precision:	0.6924991702621972
# Recall:		0.6938502673796791
# F-measure:	0.6933933933933933
# (beta 2.0)
# Fold 9/10
# --------MODEL 9 QUALITY--------
# -------| Training |-----------
# Accuracy:	0.7354664263181613
# Precision:	0.7369583460168327
# Recall:		0.7341401651871362
# F-measure:	0.7338349456878266
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.7195121951219512
# Precision:	0.7218617584745763
# Recall:		0.7236236236236235
# F-measure:	0.7210475694518248
# (beta 2.0)
# Fold 10/10
# --------MODEL 10 QUALITY--------
# -------| Training |-----------
# Accuracy:	0.7561964849031095
# Precision:	0.75921208414231
# Recall:		0.7568675961585336
# F-measure:	0.7558917886298386
# (beta 2.0)
# -------|   Test   |-----------
# Accuracy:	0.6788617886178862
# Precision:	0.6952499113789437
# Recall:		0.6821428571428572
# F-measure:	0.675742738040098
# (beta 2.0)
# Score train: 0.7425288647799906
# Score test: 0.7233040387084033

# %%
# retain only Street Location
X_corrected = pd.DataFrame(X_corrected)

for column in X.columns:
    if column not in X_corrected.columns:
        X_augmented = X_corrected.assign(columns=X[column])
        best_nb, score_train, score_test = k_fold(X_augmented, y, 10, CategoricalNB(min_categories=X_augmented.nunique()))
        print(f"---------| Adding {column} |-------")
        print("Score train: " + str(score_train))
        print("Score test: " + str(score_test))
# Out:
# ---------| Adding Domestic |-------
# Score train: 0.7623618629338963
# Score test: 0.755363549586913
# ---------| Adding Beat |-------
# Score train: 0.7941397171976914
# Score test: 0.7228876600506896
# ---------| Adding District |-------
# Score train: 0.7631729985033755
# Score test: 0.744810901550311
# ---------| Adding Ward |-------
# Score train: 0.7659678016442146
# Score test: 0.7411622395576183
# ---------| Adding Community Area |-------
# Score train: 0.7652915979748633
# Score test: 0.7314176623547611
# ---------| Adding NUM_OF_ARREST |-------
# Score train: 0.763849344398792
# Score test: 0.7565781244856982
# ---------| Adding IS_DOMESTIC |-------
# Score train: 0.761550503866314
# Score test: 0.7557700536519535
# ---------| Adding NIGHT_CRIME |-------
# Score train: 0.7612349854990368
# Score test: 0.751711596063329
# ---------| Adding HAS_STREET_ORGANIZATION |-------
# Score train: 0.761640654873823
# Score test: 0.7537441163885323
# ---------| Adding IS_RATIAL |-------
# Score train: 0.7612349448630179
# Score test: 0.7529278167275599
# ---------| Adding AVER_AGE |-------
# Score train: 0.7620463039306001
# Score test: 0.7573911326157796
# ---------| Adding IMMEDIATE_ARREST |-------
# Score train: 0.7641649034020881
# Score test: 0.7553619038214674

# %%
# add NUM_OF_ARREST
X_corrected["NUM_OF_ARREST"] = X["NUM_OF_ARREST"]

for column in X.columns:
    if column not in X_corrected.columns:
        X_augmented = X_corrected.assign(columns=X[column])
        best_nb, score_train, score_test = k_fold(X_augmented, y, 10, CategoricalNB(min_categories=X_augmented.nunique()))
        print(f"---------| Adding {column} |-------")
        print("Score train: " + str(score_train))
        print("Score test: " + str(score_test))
# Out:
# ---------| Adding Domestic |-------
# Score train: 0.7638943284715045
# Score test: 0.7561732661861031
# ---------| Adding Beat |-------
# Score train: 0.7958976313671056
# Score test: 0.7261298179783418
# ---------| Adding District |-------
# Score train: 0.7628122928832922
# Score test: 0.7456206181495013
# ---------| Adding Ward |-------
# Score train: 0.7673649086034985
# Score test: 0.7383134195714427
# ---------| Adding Community Area |-------
# Score train: 0.7648407007112521
# Score test: 0.7354794114742769
# ---------| Adding IS_DOMESTIC |-------
# Score train: 0.7629928793504415
# Score test: 0.7549586912873177
# ---------| Adding NIGHT_CRIME |-------
# Score train: 0.7638042790540422
# Score test: 0.7565797702511438
# ---------| Adding HAS_STREET_ORGANIZATION |-------
# Score train: 0.7638042384180237
# Score test: 0.7549586912873177
# ---------| Adding IS_RATIAL |-------
# Score train: 0.7636690017477552
# Score test: 0.7561716204206576
# ---------| Adding AVER_AGE |-------
# Score train: 0.7638492428087453
# Score test: 0.7557667621210625
# ---------| Adding IMMEDIATE_ARREST |-------
# Score train: 0.7660129685790114
# Score test: 0.7594170698792008

# %%
# add immediate arrests
X_corrected["IMMEDIATE_ARREST"] = X["IMMEDIATE_ARREST"]

for column in X.columns:
    if column not in X_corrected.columns:
        X_augmented = X_corrected.assign(columns=X[column])
        best_nb, score_train, score_test = k_fold(X_augmented, y, 10, CategoricalNB(min_categories=X_augmented.nunique()))
        print(f"---------| Adding {column} |-------")
        print("Score train: " + str(score_train))
        print("Score test: " + str(score_test))
# Out:
# ---------| Adding Domestic |-------
# Score train: 0.7662382953027607
# Score test: 0.7594170698792008
# ---------| Adding Beat |-------
# Score train: 0.7969343577944558
# Score test: 0.7285639050722492
# ---------| Adding District |-------
# Score train: 0.7656521004148531
# Score test: 0.7476514927092591
# ---------| Adding Ward |-------
# Score train: 0.7698892180857916
# Score test: 0.7395345775320101
# ---------| Adding Community Area |-------
# Score train: 0.7674551205650356
# Score test: 0.7379118528027386
# ---------| Adding IS_DOMESTIC |-------
# Score train: 0.7652015688754105
# Score test: 0.7582024949804153
# ---------| Adding NIGHT_CRIME |-------
# Score train: 0.7655622135414657
# Score test: 0.7590122115796056
# ---------| Adding HAS_STREET_ORGANIZATION |-------
# Score train: 0.7658776912727242
# Score test: 0.7573927783812252
# ---------| Adding IS_RATIAL |-------
# Score train: 0.765652323912956
# Score test: 0.7577943451499293
# ---------| Adding AVER_AGE |-------
# Score train: 0.7660128873069738
# Score test: 0.7586073532800105

# %%
def hill_climbing_feature_addition(X_start, X_complete, y, n_folds=10):
    best_model, train_score, test_score = k_fold(X_start, y, n_folds, CategoricalNB(min_categories=X_start.nunique()))
    print(f"Initial Scores: \n\tTR: {train_score} \n\tTE{test_score}")


    while len(X.columns) > len(X_start.columns):
        column_scores = {}
        for column in X.columns:
            if column not in X_start.columns:
                X_augmented = X_start.assign(columns=X[column])
                best_nb, score_train, score_test = k_fold(X_augmented, y, 10, CategoricalNB(min_categories=X_augmented.nunique()))
                column_scores[column] = (score_train, score_test)

        best_feature = max(column_scores, key=lambda x: column_scores[x][1])
        X_start[best_feature] = X[best_feature]
        print(f"---------| Adding {best_feature} |-------")
        print("Score train: " + str(score_train))
        print("Score test: " + str(score_test))

# %%
hill_climbing_feature_addition(pd.DataFrame(X["Location Description"]), X, y)
# Out:
# Initial Scores:
# 	TR: 0.7615955895290732
# 	TE0.7537457621539778
# ---------| Adding AVER_AGE |-------
# Score train: 0.7641649034020881
# Score test: 0.7553619038214674
# ---------| Adding IMMEDIATE_ARREST |-------
# Score train: 0.7641648627660694
# Score test: 0.760230078009282
# ---------| Adding IS_RATIAL |-------
# Score train: 0.7641648627660695
# Score test: 0.760230078009282
# ---------| Adding NIGHT_CRIME |-------
# Score train: 0.7646606628303557
# Score test: 0.7598252197096869
# ---------| Adding HAS_STREET_ORGANIZATION |-------
# Score train: 0.7644353157885969
# Score test: 0.7602317237747276
# ---------| Adding Domestic |-------
# Score train: 0.7564575103692961
# Score test: 0.7379167900990751
# ---------| Adding NUM_OF_ARREST |-------
# Score train: 0.7478487494874783
# Score test: 0.7237121885388895
# ---------| Adding District |-------
# Score train: 0.745413432886161
# Score test: 0.7293867877950035
# ---------| Adding Community Area |-------
# Score train: 0.7442868399034326
# Score test: 0.7172311642144763
# ---------| Adding IS_DOMESTIC |-------
# Score train: 0.7572681176705321
# Score test: 0.7212797472104275
# ---------| Adding Ward |-------
# Score train: 0.7586653871738909
# Score test: 0.7111368947697574
# ---------| Adding Beat |-------
# Score train: 0.7787690618484269
# Score test: 0.697732135216089

# %%
from sklearn.neighbors import KNeighborsClassifier
df = ds_new
my_model = KNeighborsClassifier()

x = df.drop(["IS_HOMICIDE", "CASE_NUMBER", "VICTIM_RACE", "ARRESTED_RACE", "NUM_OF_DEAD", "IS_KILLED_A_CHILD"], axis=1)
y = df["IS_HOMICIDE"]


for k in range(1, 31, 2):

    best_knn, tr_scores, te_scores = k_fold(x, y, 10, KNeighborsClassifier(n_neighbors=k))
    print(f"TR {tr_scores}")
    print(f"TE {te_scores}")
    k_scores.append(te_scores)

best_k = [np.argmax(k_scores)]
print("Best k is: ", best_k)
# Out:
# TR 1.0
# TE 0.5171998946710115
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [75], in <cell line: 9>()
#      12     print(f"TR {tr_scores}")
#      13     print(f"TE {te_scores}")
# ---> 14     k_scores.append(te_scores)
#      16 best_k = [np.argmax(k_scores)]
#      17 print("Best k is: ", best_k)
#
# NameError: name 'k_scores' is not defined

# %%
from sklearn.naive_bayes import GaussianNB

X: pd.DataFrame = ds_new.drop(columns=["CASE_NUMBER", "NUM_OF_DEAD", "IS_KILLED_A_CHILD",
                                            "IS_HOMICIDE", "VICTIM_RACE", "ARRESTED_RACE", "AVER_AGE"])

y: pd.Series = ds_new["IS_HOMICIDE"]
    
best_model, train_score, test_score = k_fold(X, y, 10, verbose=True, classifier=GaussianNB())

print(str(test_score))

# %%
from sklearn.svm import SVC


best_model, train_score, test_score = k_fold(X, y, 10, verbose=True, classifier=SVC(kernel='sigmoid', gamma='auto'))
print(str(test_score))
